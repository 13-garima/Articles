# %% [markdown]
# <a href="https://colab.research.google.com/github/13-garima/Articles/blob/main/webscrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Extracting Favism reviews
#
# 1] Install bs4
# Beautiful soup
# bs4: Beautiful Soup(bs4) is a Python library for pulling data out of HTML and XML files.
# This module does not come built-in with Python.
# To install this type the below command in the terminal.

# %%
pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# requests: Request allows you to send HTTP/1.1 requests extremely easily. This module also does not come built-in with Python. To install this type the below command in the terminal.
#
# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup
  
HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
            AppleWebKit/537.36 (KHTML, like Gecko) \
            Chrome/106.0.0.0 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})


def getdata(url):
  r = requests.get(url,headers=HEADERS)
  return r.text

def html_code(url):

  htmldata = getdata(url)
  soup = BeautifulSoup(htmldata,'html.parser')

  return(soup)

url = "https://favism.in/products/closet-organiser-saree-cover-price?pr_prod_strat=collection_fallback&pr_rec_id=bc2d2e394&pr_rec_pid=5357768442015&pr_ref_pid=5352971894943&pr_seq=uniform"

soup =html_code(url)
print(soup)
# Out:
# <!DOCTYPE doctype html>
#
# <html class="no-js" lang="en">
# <head>
# <meta content="a_4tCLVXgK18vLhpxJofv48gl9OEqaHGGXZb1fscCN8" name="google-site-verification"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MQXQT3T');</script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="" name="theme-color"/>
# <link href="https://favism.in/products/closet-organiser-saree-cover-price" rel="canonical"/>
# ...

# %% [markdown]
# # Scrape Customer Name

# %%
def customer_data(soup):
  data_str =""
  customer_list =[]

  for item in soup.find_all("span",class_="jdgm-rev__author"):
    data_str = data_str + item.get_text()
    customer_list.append(data_str)
    data_str =""
  return customer_list

customer = customer_data(soup)
print(customer)
# Out:
# ['V.S.', 'V.S.', 'Madanmohan Chodavarapu', 'Sunita Pathania', 'Neetu Rai']

# %%
def cus_rev(soup):
    # find the Html tag
    # with find()
    # and convert into string
    data_str = ""
  
    for item in soup.find_all("div", class_="jdgm-rev__body"):
        data_str = data_str + item.get_text()
  
    result = data_str.split("\n")
    return (result)
  
  
rev_data = cus_rev(soup)
rev_result = []
for i in rev_data:
    if i is " ":
        pass
    else:
        rev_result.append(i)
rev_result
# Out:
# ["GoodExcellentNon-woven single saree cover | garment cover combo pack of 12 pcs.Non-woven single saree cover | closet storage | garment cover combo pack of 12 pcs.We received total 12 packets, the quality of the packet is perfect but it's space is small, it can contain only one saree at a time. If your saree is thin and soft then a packet could contain two saree but if your saree is quite big then it can contain one saree along with the saree's blouse."]

# %%
import pandas as pd
  
# initialise data of lists.
data = {'Name': customer_data,
        'review': rev_result}
  
# Create DataFrame
df = pd.DataFrame(data)
  
# Save the output.
df.to_csv('favism.csv')

# %% [markdown]
# # New Section
